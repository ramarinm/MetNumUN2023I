# %% [markdown]
# Link LinkedIn: https://www.linkedin.com/in/ra%C3%BAl-ignacio-mar%C3%ADn-medina-153b1b24b/recent-activity/

# %% [markdown]
# ![ramarinmdataanalysiswithpython.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![ramarinmdatasciencewithpython.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![ramarinmdatavisualizationwithpython.jpg](data:image/jpeg;base64,...)
